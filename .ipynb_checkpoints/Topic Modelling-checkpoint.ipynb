# %%
import nltk
from nltk.corpus import twitter_samples
from nltk.corpus import stopwords
import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy
import re
import string

import sqlite3
from sqlite3 import Error

pd.options.display.max_colwidth

#nlp packages
#remove stop words
import re
import nltk
from nltk.corpus import stopwords

# %% [markdown]
# This notebook will demonstrate the building of Topic Modelling on the Tweet database

# %%
#Step 1 - Set up connection to the database where I am storing tweets and download them;
db_file = "C:\SQLLite\Twitter_database.db"
conn = sqlite3.connect(db_file)  

#Step 2 - Pull tweets from database
df = pd.read_sql_query("SELECT * FROM tweets", conn)
df.head()
# Out:
#              author_id                 created_at            created_at_raw  \
# 0  1417101905583607817  2022-02-17 18:12:29+00:00  2022-02-17T18:12:29.000Z
# 1  1495445778000715782  2022-02-20 17:20:11+00:00  2022-02-20T17:20:11.000Z
# 2             28096877  2022-02-18 13:50:18+00:00  2022-02-18T13:50:18.000Z
# 3  1370977627989630976  2022-02-17 18:39:28+00:00  2022-02-17T18:39:28.000Z
# 4  1474326342363537411  2022-02-23 19:13:49+00:00  2022-02-23T19:13:49.000Z
#
#   geo             tweet_id lang  like_count  quote_count  reply_count  \
# 0      1494374205537853446   en         628            3           30
# 1      1495448209887481861   en         220            0            1
# 2      1494670613063024644   en         984            2           27
# 3      1494380997437116422   en        2387           11          143
# 4      1496563967120244741   en           0            0            0
#
#    retweet_count               source  \
# 0            218   Twitter for iPhone
# 1            126      Twitter Web App
# 2            245   Twitter for iPhone
# 3            620      Twitter Web App
# 4              0  Twitter for Android
#
#                                                 text  \
# 0  Thank you @RevolutApp \n\nWelcome to #SHIBARMY...
# 1  Superb, sobering article on shameful, systemic...
# 2  To all @RevolutApp users, grab your $SHIB now ...
# 3  .@RevolutApp just tell everyone how much you l...
# 4  @JaneDoe69086964 @JamesDelingpole @LloydsBank ...
#
#              normalised_date
# 0  2022-02-17 00:00:00+00:00
# 1  2022-02-20 00:00:00+00:00
# 2  2022-02-18 00:00:00+00:00
# 3  2022-02-17 00:00:00+00:00
# 4  2022-02-23 00:00:00+00:00

# %% [markdown]
# General analysis on the dataframe

# %%
df.describe(include='all')
# Out:
#            author_id                 created_at            created_at_raw  \
# count   1.745000e+04                      17450                     17450
# unique           NaN                      17139                     17139
# top              NaN  2022-02-24 18:00:30+00:00  2022-02-24T18:00:30.000Z
# freq             NaN                         11                        11
# mean    4.813238e+17                        NaN                       NaN
# std     6.202511e+17                        NaN                       NaN
# min     1.033800e+04                        NaN                       NaN
# 25%     2.036599e+08                        NaN                       NaN
# 50%     1.688174e+09                        NaN                       NaN
# 75%     1.184463e+18                        NaN                       NaN
# max     1.502920e+18                        NaN                       NaN
#
#           geo      tweet_id   lang    like_count   quote_count   reply_count  \
# count   17450  1.745000e+04  17450  17450.000000  17450.000000  17450.000000
# unique    189           NaN      1           NaN           NaN           NaN
# top                     NaN     en           NaN           NaN           NaN
# freq    17089           NaN  17450           NaN           NaN           NaN
# mean      NaN  1.499612e+18    NaN      0.691748      0.006132      0.268596
# std       NaN  1.810740e+15    NaN     34.295569      0.153352      3.563157
# min       NaN  1.494205e+18    NaN      0.000000      0.000000      0.000000
# 25%       NaN  1.498279e+18    NaN      0.000000      0.000000      0.000000
# 50%       NaN  1.499449e+18    NaN      0.000000      0.000000      0.000000
# 75%       NaN  1.501197e+18    NaN      0.000000      0.000000      0.000000
# max       NaN  1.502944e+18    NaN   3511.000000     11.000000    440.000000
#
#         retweet_count              source              text  \
# count    17450.000000               17450             17450
# unique            NaN                  79             17192
# top               NaN  Twitter for iPhone  @RevolutApp Done
# freq              NaN                7740                21
# mean         0.124241                 NaN               NaN
# std          5.685436                 NaN               NaN
# min          0.000000                 NaN               NaN
# 25%          0.000000                 NaN               NaN
# 50%          0.000000                 NaN               NaN
# 75%          0.000000                 NaN               NaN
# max        620.000000                 NaN               NaN
#
#                   normalised_date
# count                       17450
# unique                         25
# top     2022-03-01 00:00:00+00:00
# freq                         1664
# mean                          NaN
# std                           NaN
# min                           NaN
# 25%                           NaN
# 50%                           NaN
# 75%                           NaN
# max                           NaN

# %%
#PreProcessing on tweets
#remove stop words
import re
import nltk
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

#Remove any rows with a "nan" in them
df = df.dropna(axis=0, how = 'any')

#Make it so that any non readable text gets converted into nothing
def removetext(text):
    return ''.join([i if ord(i) < 128 else '' for i in text])

#Here I am doing the actual removing
df['text'] = df['text'].apply(removetext)

#remove @monzo etc
def clean_tweet_handles(raw_tweet):
    handles_only = re.sub(r"()@\w+",r"\1",raw_tweet)
    #print(handles_only)
    words = handles_only.lower().split()                             
    stops = set(stopwords.words("english"))                  
    meaningful_words = [w for w in words if not w in stops] 
    return( " ".join( meaningful_words )) 

#remove URLS
def remove_urls(raw_tweet):
    tweet = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', raw_tweet,flags=re.MULTILINE)
#     re.sub(r"http\S+|www\S+|https\S+", '', tweet, flags=re.MULTILINE
    #print(handles_only)
    words = tweet.lower().split()                             
    stops = set(stopwords.words("english"))                  
    meaningful_words = [w for w in words if not w in stops] 
    return( " ".join( meaningful_words )) 

def tweet_to_words(raw_tweet):
    letters_only = re.sub("[^a-zA-Z]", " ",raw_tweet) 
    words = letters_only.lower().split()                             
    stops = set(stopwords.words("english"))                  
    meaningful_words = [w for w in words if not w in stops] 
    return( " ".join( meaningful_words )) 

def stemming(raw_tweet):
    letters_only = re.sub("[^a-zA-Z]", " ",raw_tweet) 
    words = letters_only.lower().split()   
    stops = set(stopwords.words("english"))      
    ps = PorterStemmer()
    stemmed_words = [ps.stem(w) for w in words if not w in stops]
    return( " ".join( stemmed_words)) 
    
def lemmatizer(raw_tweet):
    letters_only = re.sub("[^a-zA-Z]", " ",raw_tweet) 
    words = letters_only.lower().split()   
    stops = set(stopwords.words("english"))      
#     ps = PorterStemmer()
#     stemmed_words = [ps.stem(w) for w in words if not w in stops]   
    lemmatizer = WordNetLemmatizer()
    lemma_words = [lemmatizer.lemmatize(w, pos='a') for w in words if not w in stops]
    return( " ".join( lemma_words)) 

#removing links

def clean_tweet_length(raw_tweet):
    letters_only = re.sub("[^a-zA-Z]", " ",raw_tweet) 
    words = letters_only.lower().split()                             
    stops = set(stopwords.words("english"))                  
    meaningful_words = [w for w in words if not w in stops] 
    return(len(meaningful_words)) 

df_clean=df
df_clean['no_handles']=df_clean['text'].apply(lambda x: clean_tweet_handles(x))
df_clean['remove_urls']=df_clean['no_handles'].apply(lambda x: remove_urls(x))
df_clean['clean_tweet']=df_clean['remove_urls'].apply(lambda x: tweet_to_words(x))
df_clean['stemmed_tweet']=df_clean['clean_tweet'].apply(lambda x: stemming(x))
df_clean['lemmatizer_tweet']=df_clean['clean_tweet'].apply(lambda x: lemmatizer(x))
df_clean['Tweet_length']=df_clean['text'].apply(lambda x: clean_tweet_length(x))

df_clean.head(10)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kryzw\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#              author_id                 created_at            created_at_raw  \
# 0  1417101905583607817  2022-02-17 18:12:29+00:00  2022-02-17T18:12:29.000Z
# 1  1495445778000715782  2022-02-20 17:20:11+00:00  2022-02-20T17:20:11.000Z
# 2             28096877  2022-02-18 13:50:18+00:00  2022-02-18T13:50:18.000Z
# 3  1370977627989630976  2022-02-17 18:39:28+00:00  2022-02-17T18:39:28.000Z
# 4  1474326342363537411  2022-02-23 19:13:49+00:00  2022-02-23T19:13:49.000Z
# 5             97411152  2022-02-17 11:47:57+00:00  2022-02-17T11:47:57.000Z
# 6             28096877  2022-02-17 16:15:11+00:00  2022-02-17T16:15:11.000Z
# 7  1371908442470879237  2022-02-18 18:02:09+00:00  2022-02-18T18:02:09.000Z
# 8  1445039625274286083  2022-02-19 12:26:55+00:00  2022-02-19T12:26:55.000Z
# 9  1164106949421481986  2022-02-17 21:13:13+00:00  2022-02-17T21:13:13.000Z
#
#   geo             tweet_id lang  like_count  quote_count  reply_count  \
# 0      1494374205537853446   en         628            3           30
# 1      1495448209887481861   en         220            0            1
# 2      1494670613063024644   en         984            2           27
# 3      1494380997437116422   en        2387           11          143
# 4      1496563967120244741   en           0            0            0
# 5      1494277434904092679   en        3511           11          440
# 6      1494344687775330308   en         762            2           26
# 7      1494733992553324544   en           1            0            0
# 8      1495012017379364874   en          80            1           14
# 9      1494419690508144649   en           0            0            1
#
#    retweet_count               source  \
# 0            218   Twitter for iPhone
# 1            126      Twitter Web App
# 2            245   Twitter for iPhone
# 3            620      Twitter Web App
# 4              0  Twitter for Android
# 5             61   Twitter for iPhone
# 6            158   Twitter for iPhone
# 7              0   Twitter for iPhone
# 8             42  Twitter for Android
# 9              0      Twitter Web App
#
#                                                 text  \
# 0  Thank you @RevolutApp \n\nWelcome to #SHIBARMY...
# 1  Superb, sobering article on shameful, systemic...
# 2  To all @RevolutApp users, grab your $SHIB now ...
# 3  .@RevolutApp just tell everyone how much you l...
# 4  @JaneDoe69086964 @JamesDelingpole @LloydsBank ...
# 5  After many years of only banking with @HSBC_UK...
# 6  Just grabbed another 10000000 $SHIB on that @R...
# 7  @shibainuart @ShytoshiKusama @RevolutApp Love ...
# 8  @RevolutApp Being one of the 15 million users ...
# 9  Just caught @RevolutApp storing my card inform...
#
#              normalised_date  \
# 0  2022-02-17 00:00:00+00:00
# 1  2022-02-20 00:00:00+00:00
# 2  2022-02-18 00:00:00+00:00
# 3  2022-02-17 00:00:00+00:00
# 4  2022-02-23 00:00:00+00:00
# 5  2022-02-17 00:00:00+00:00
# 6  2022-02-17 00:00:00+00:00
# 7  2022-02-18 00:00:00+00:00
# 8  2022-02-19 00:00:00+00:00
# 9  2022-02-17 00:00:00+00:00
#
#                                           no_handles  \
# 0  thank welcome #shibarmy! best app never bought...
# 1  superb, sobering article shameful, systemic fr...
# 2  users, grab $shib go moon. last chance https:/...
# 3  . tell everyone much love $shib, love sam, chi...
# 4  first ever referral based reward token bsc gai...
# 5  many years banking , thats it. enough. wanted ...
# 6  grabbed another 10000000 $shib https://t.co/fe...
# 7  love shib #shiberse #shibaarmy https://t.co/lr...
# 8  one 15 million users #revolut holds #babydoge ...
# 9  caught storing card information even deleting ...
#
#                                          remove_urls  \
# 0  thank welcome #shibarmy! best app never bought...
# 1  superb, sobering article shameful, systemic fr...
# 2             users, grab $shib go moon. last chance
# 3  . tell everyone much love $shib, love sam, chi...
# 4  first ever referral based reward token bsc gai...
# 5  many years banking , thats it. enough. wanted ...
# 6                     grabbed another 10000000 $shib
# 7                     love shib #shiberse #shibaarmy
# 8  one 15 million users #revolut holds #babydoge ...
# 9  caught storing card information even deleting ...
#
#                                          clean_tweet  \
# 0  thank welcome shibarmy best app never bought c...
# 1  superb sobering article shameful systemic frau...
# 2                users grab shib go moon last chance
# 3  tell everyone much love shib love sam chief pe...
# 4  first ever referral based reward token bsc gai...
# 5  many years banking thats enough wanted speak h...
# 6                               grabbed another shib
# 7                       love shib shiberse shibaarmy
# 8  one million users revolut holds babydoge expec...
# 9  caught storing card information even deleting ...
#
#                                        stemmed_tweet  \
# 0  thank welcom shibarmi best app never bought cr...
# 1  superb sober articl shame system fraud prevent...
# 2                  user grab shib go moon last chanc
# 3  tell everyon much love shib love sam chief pet...
# 4  first ever referr base reward token bsc gain t...
# 5  mani year bank that enough want speak human ma...
# 6                                    grab anoth shib
# 7                        love shib shibers shibaarmi
# 8  one million user revolut hold babydog expect a...
# 9  caught store card inform even delet someth pro...
#
#                                     lemmatizer_tweet  Tweet_length
# 0  thank welcome shibarmy best app never bought c...            12
# 1  superb sobering article shameful systemic frau...            17
# 2                users grab shib go moon last chance            12
# 3  tell everyone much love shib love sam chief pe...            12
# 4  first ever referral based reward token bsc gai...            35
# 5  many years banking thats enough wanted speak h...            28
# 6                               grabbed another shib             7
# 7                       love shib shiberse shibaarmy            12
# 8  one million users revolut holds babydoge expec...            17
# 9  caught storing card information even deleting ...            18

# %% [markdown]
# The inital ceaning is now complete - we will now import the models required for topic modelling

# %%
#Yopic modelling
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import NMF

# the vectorizer object will be used to transform text to vector form
vectorizer = CountVectorizer(max_df=0.7, min_df=75)

# apply transformation
tf = vectorizer.fit_transform(df['lemmatizer_tweet']).toarray()

# tf_feature_names tells us what word each column in the matric represents
tf_feature_names = vectorizer.get_feature_names()
print(tf_feature_names)
# Out:
# ['able', 'absolute', 'absolutely', 'access', 'account', 'accounts', 'actually', 'add', 'address', 'advice', 'advise', 'agent', 'ago', 'allow', 'almost', 'already', 'also', 'always', 'amount', 'amp', 'another', 'answer', 'anyone', 'anything', 'app', 'apple', 'application', 'apply', 'around', 'asap', 'ask', 'asked', 'asking', 'available', 'aware', 'away', 'back', 'bad', 'balance', 'bank', 'banking', 'banks', 'barclays', 'believe', 'best', 'big', 'bit', 'block', 'blocked', 'bonds', 'branch', 'branches', 'brutal', 'business', 'buy', 'call', 'called', 'calling', 'calls', 'cannot', 'cant', 'card', 'cards', 'care', 'case', 'cash', 'change', 'changed', 'charge', 'chat', 'check', 'checked', 'cheque', 'clear', 'click', 'climate', 'close', 'closed', 'closing', 'co', 'code', 'come', 'coming', 'companies', 'company', 'complaint', 'complete', 'confirm', 'contact', 'contacted', 'could', 'covid', 'credit', 'crypto', 'current', 'currently', 'customer', 'customers', 'cut', 'date', 'day', 'days', 'deal', 'debit', 'declined', 'deposit', 'despite', 'details', 'didnt', 'different', 'digital', 'direct', 'dm', 'doesnt', 'donate', 'donation', 'donations', 'done', 'dont', 'due', 'early', 'easy', 'either', 'else', 'email', 'end', 'enough', 'error', 'etc', 'even', 'ever', 'every', 'everyone', 'everything', 'exchange', 'experience', 'explain', 'far', 'feel', 'fees', 'finance', 'financial', 'find', 'fine', 'first', 'fix', 'fixed', 'form', 'forward', 'fraud', 'fraudulent', 'free', 'full', 'fund', 'funds', 'gas', 'gave', 'get', 'getting', 'give', 'given', 'giving', 'go', 'going', 'gone', 'good', 'got', 'great', 'guys', 'hacked', 'half', 'halifax', 'happened', 'happening', 'happy', 'hard', 'havent', 'hear', 'hello', 'help', 'helpful', 'hey', 'hi', 'high', 'hold', 'holding', 'home', 'hope', 'hour', 'hours', 'house', 'however', 'hsbc', 'id', 'idea', 'ill', 'im', 'info', 'information', 'instagram', 'instead', 'insurance', 'interest', 'international', 'internet', 'investors', 'isnt', 'issue', 'issues', 'ive', 'join', 'joke', 'keep', 'keeps', 'kindly', 'know', 'last', 'late', 'leave', 'left', 'less', 'let', 'letter', 'like', 'line', 'link', 'list', 'live', 'lloyds', 'loan', 'local', 'locked', 'log', 'login', 'long', 'look', 'looking', 'looks', 'lost', 'lot', 'love', 'made', 'make', 'making', 'many', 'march', 'may', 'maybe', 'mean', 'message', 'messages', 'might', 'mine', 'mins', 'minutes', 'mobile', 'moment', 'money', 'month', 'months', 'monzo', 'morning', 'mortgage', 'move', 'moved', 'much', 'name', 'natwest', 'nearly', 'need', 'needs', 'never', 'new', 'next', 'nice', 'nothing', 'number', 'offer', 'office', 'oh', 'oil', 'ok', 'old', 'one', 'online', 'open', 'opened', 'option', 'order', 'page', 'paid', 'part', 'password', 'pay', 'paying', 'payment', 'payments', 'people', 'person', 'personal', 'phone', 'pin', 'pipeline', 'place', 'please', 'pm', 'point', 'poor', 'possible', 'post', 'pretty', 'problem', 'problems', 'process', 'provide', 'put', 'putin', 'putting', 'question', 'queue', 'quick', 'quite', 'rate', 'rather', 'read', 'real', 'really', 'reason', 'receive', 'received', 'recently', 'refund', 'regarding', 'register', 'reply', 'report', 'request', 'resolved', 'response', 'revolut', 'ridiculous', 'right', 'russia', 'russian', 'safe', 'said', 'santander', 'savings', 'say', 'saying', 'says', 'scam', 'security', 'see', 'seem', 'seems', 'send', 'sending', 'sent', 'service', 'services', 'set', 'several', 'show', 'showing', 'side', 'sign', 'similar', 'since', 'site', 'small', 'someone', 'something', 'son', 'soon', 'sorry', 'sort', 'sorted', 'speak', 'spend', 'spent', 'st', 'staff', 'starling', 'start', 'started', 'statement', 'statements', 'still', 'stop', 'support', 'sure', 'switch', 'system', 'take', 'taken', 'takes', 'taking', 'talk', 'team', 'telephone', 'tell', 'telling', 'text', 'th', 'thank', 'thanks', 'thats', 'theres', 'thing', 'things', 'think', 'though', 'thought', 'time', 'times', 'today', 'told', 'tomorrow', 'took', 'top', 'transaction', 'transactions', ' ...

# %%
#topics
number_of_topics = 4
model = LatentDirichletAllocation(n_components=number_of_topics, random_state=0)
# model = NMF(n_components=number_of_topics, random_state=0, alpha=.1, l1_ratio=.5,max_iter=500)
model.fit(tf)

def display_topics(model, feature_names, no_top_words):
    topic_dict = {}
    for topic_idx, topic in enumerate(model.components_):
        topic_dict["Topic %d words" % (topic_idx)]= ['{}'.format(feature_names[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
        topic_dict["Topic %d weights" % (topic_idx)]= ['{:.1f}'.format(topic[i])
                        for i in topic.argsort()[:-no_top_words - 1:-1]]
    return pd.DataFrame(topic_dict)

# %%
no_top_words = 20
display_topics(model, tf_feature_names, no_top_words)
# Out:
#    Topic 0 words Topic 0 weights Topic 1 words Topic 1 weights Topic 2 words  \
# 0          money           896.6           app          1545.2       account
# 1        revolut           689.7          card           969.1        please
# 2           help           578.4        thanks           797.4         thank
# 3        ukraine           460.2        online           766.5          card
# 4          banks           442.7       banking           752.2            hi
# 5            one           386.8         tried           489.9           get
# 6         people           336.9       working           465.8          need
# 7           want           291.1           ive           444.7       payment
# 8            big           285.3           get           439.9          help
# 9        support           285.2            hi           433.1          bank
# 10         putin           275.2         issue           431.2         email
# 11       russian           274.2         phone           426.5          sent
# 12          good           267.5       account           389.5        credit
# 13          stop           267.2           use           386.2            dm
# 14          also           266.4          cant           378.1        number
# 15            uk           261.1          help           373.0         today
# 16           war           253.2        trying           370.4        thanks
# 17          need           246.6          chat           368.9            us
# 18       account           237.1            im           325.2         would
# 19        russia           214.2           try           321.1      business
#
#    Topic 2 weights Topic 3 words Topic 3 weights
# 0           1089.1          bank          1100.3
# 1            802.4       account          1049.3
# 2            686.2       service           868.1
# 3            658.4      customer           749.9
# 4            598.9           get           669.1
# 5            513.2          call           616.7
# 6            478.5         money           590.9
# 7            469.0          hold           561.0
# 8            424.3         still           546.0
# 9            414.9          time           525.6
# 10           409.3         phone           489.7
# 11           390.8        branch           476.1
# 12           367.5            im           449.5
# 13           365.1          back           425.7
# 14           336.9          done           398.1
# 15           324.3          days           397.1
# 16           282.6       someone           360.2
# 17           279.1       waiting           351.6
# 18           277.2         hours           349.5
# 19           274.6          told           347.5

# %%
# Log Likelyhood: Higher the better
print("Log Likelihood: ", model.score(tf))
# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", model.perplexity(tf))
# Out:
# Log Likelihood:  -704006.660978474
# Perplexity:  363.6900363234653

# %%
#thank welcome shibarmy best app never bought

# https://towardsdatascience.com/latent-dirichlet-allocation-for-topic-modelling-explained-algorithm-and-python-scikit-learn-c65a82e7304d
#testing the model
# @CooperativeBank why can't I access my money thru m-banking?
text7 = 'save the climate'
print (model.transform(vectorizer.transform([text7])))
# Out:
# [[0.62496364 0.12500102 0.12500111 0.12503423]]

# %%
# the dataset to predict on (first two samples were also in the training set so one can compare)
data_samples = ["phone hours",
                "save climate",
                "branch closed",
                "save ukraine",
                "bitcoin shib",
                "buy crypto",
                "thank you",
                "can't log on"
               ]
# Vectorize the training set using the model features as vocabulary

# transform method returns a matrix with one line per document, columns being topics weight
predict = model.transform(vectorizer.transform(data_samples))
print(predict)

topic_pred = []
for n in range(predict.shape[0]):
    topic_most_pr = predict[n].argmax()
#     print("doc: {} topic: {}\n".format(n,topic_most_pr))
    topic_pred.append(topic_most_pr)
#     print(topic_pred)

predictdf = pd.DataFrame()
predictdf['text'] = data_samples
predictdf['topic'] = topic_pred
predictdf
# Out:
# [[0.08339357 0.08697467 0.08405108 0.74558068]
#  [0.62496364 0.12500102 0.12500111 0.12503423]
#  [0.0833339  0.08333989 0.0837519  0.74957431]
#  [0.62499946 0.12500018 0.1250002  0.12500016]
#  [0.25       0.25       0.25       0.25      ]
#  [0.42381552 0.08426555 0.08549092 0.406428  ]
#  [0.12500039 0.12500021 0.62499923 0.12500017]
#  [0.12500083 0.62499811 0.12500058 0.12500047]]
#             text  topic
# 0    phone hours      3
# 1   save climate      0
# 2  branch closed      3
# 3   save ukraine      0
# 4   bitcoin shib      0
# 5     buy crypto      0
# 6      thank you      2
# 7   can't log on      1

# %%
#Pickle and recall


from joblib import dump, load
dump(model, 'C:/Dev_And_Apps/Twitter_Extract_app/Trained_Models/LDA_Model.joblib')
# Out:
# ['C:/Dev_And_Apps/Twitter_Extract_app/Trained_Models/LDA_Model.joblib']

# %%
# then reload it with
clf = load('C:/Dev_And_Apps/Twitter_Extract_app/Trained_Models/LDA_Model.joblib')

# %%
#recall model
# the dataset to predict on (first two samples were also in the training set so one can compare)
data_samples = ["phone hours",
                "save climate",
                "branch closed",
                "save ukraine",
                "bitcoin shib",
                "buy crypto",
                "thank you",
                "can't log on"
               ]
# Vectorize the training set using the model features as vocabulary

# transform method returns a matrix with one line per document, columns being topics weight
predict = clf.transform(vectorizer.transform(data_samples))
print(predict)

topic_pred = []
for n in range(predict.shape[0]):
    topic_most_pr = predict[n].argmax()
#     print("doc: {} topic: {}\n".format(n,topic_most_pr))
    topic_pred.append(topic_most_pr)
#     print(topic_pred)

predictdf = pd.DataFrame()
predictdf['text'] = data_samples
predictdf['topic'] = topic_pred
predictdf
# Out:
# [[0.08339357 0.08697467 0.08405108 0.74558068]
#  [0.62496364 0.12500102 0.12500111 0.12503423]
#  [0.0833339  0.08333989 0.0837519  0.74957431]
#  [0.62499946 0.12500018 0.1250002  0.12500016]
#  [0.25       0.25       0.25       0.25      ]
#  [0.42381552 0.08426555 0.08549092 0.406428  ]
#  [0.12500039 0.12500021 0.62499923 0.12500017]
#  [0.12500083 0.62499811 0.12500058 0.12500047]]
#             text  topic
# 0    phone hours      3
# 1   save climate      0
# 2  branch closed      3
# 3   save ukraine      0
# 4   bitcoin shib      0
# 5     buy crypto      0
# 6      thank you      2
# 7   can't log on      1

# %%
# Log Likelyhood: Higher the better
print("Log Likelihood: ", model.score(tf))

# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", model.perplexity(tf))

# See model parameters
print(model.get_params())
# Out:
# Log Likelihood:  -501246.2535732943
# Perplexity:  209.77939084719168
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.7, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 4, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': 0, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}

# %%
numtopics = [2,3,4,5,10,15,20]
LOG=[]
PERP=[]
for topic in numtopics:
    model = LatentDirichletAllocation(n_components=topic, random_state=0)
    model.fit(tf)
#     print("Log Likelihood: ", model.score(tf))
#     print("Perplexity: ", model.perplexity(tf))
    LOG.append(model.score(tf))
    PERP.append(model.perplexity(tf))
    
print(LOG,PERP)
# Out:
# [-698315.1078702742, -701873.0324747106, -704006.660978474, -707524.7658743003, -711702.8805515856, -717241.7499821025, -722879.5111090295] [346.76010779021584, 357.24866199576326, 363.6900363234653, 374.56573502198364, 387.90500856762134, 406.3238308593348, 425.96989528634043]

# %%
Index = numtopics
plt.plot(Index,PERP)

# %%
Index = numtopics
plt.plot(Index,LOG)
